# %%
import pandas as pd
import numpy as np
pd.set_option("display.max_rows", None, "display.max_columns", None)

# %%
df=pd.read_excel('2018_data.xlsx')
df.dropna(inplace=True)

# %%
df.columns=['Why_take_course', 'Expectation_from_course']

# %%
df['Combined'] = df['Why_take_course'].astype(str) + df['Expectation_from_course'].astype(str)

# %%
df['School'] = 0
df['Communication and new friends'] = 0
df['Challenge'] = 0
df['Creative and new experience'] = 0
df['Teamwork and leadership'] = 0
df['STEM'] = 0
df['Personal growth'] = 0
df['Interest and fun'] = 0
df.drop('Why_take_course', inplace=True, axis=1)
df.drop('Expectation_from_course', inplace=True, axis=1)
df
# Out:
#                                               Combined  School  \
# 0                                 我想看到自己能力的不足學到如何成為領導者       0
# 1                             認識更多朋友，提升自己能力英文提升，動手能力提升       0
# 2                                   因為我覺得他可以提升自己的英語的能力       0
# 3                                       增加自己的履歷堅強不放棄團結       0
# 4                                            見見世面英語，成長       0
# 5                                             想要鍛煉自己團結       0
# 6                                          為了鍛煉領導力更多知識       0
# 7                                             學習領導力，團結       0
# 8                                               學習體驗知識       0
# 9      機會難得 可以接觸國際上的朋友 和他們一起交流的學習可以學到一些在學校學不到的東西 提高自信心       0
# 10                                            體驗學習知識智慧       0
# 11                           想學到不一樣的知識提高自己的積極性  主動動手能力       0
# 12                                         我喜歡挑戰創造力和知識       0
# 13                                            暑假提升自己創新       0
# ...

# %%
df.loc[df['Combined'].str.contains('學校'), 'School'] = 1 
df.loc[df['Combined'].str.contains('老師'), 'School'] = 1 
df.loc[df['Combined'].str.contains('School'), 'School'] = 1 
df.loc[df['Combined'].str.contains('school'), 'School'] = 1 
df.loc[df['Combined'].str.contains('Teacher'), 'School'] = 1 
df.loc[df['Combined'].str.contains('teacher'), 'School'] = 1

# %%
df.loc[df['Combined'].str.contains('communi'), 'Communication and new friends'] = 1 
df.loc[df['Combined'].str.contains('Communi'), 'Communication and new friends'] = 1 
df.loc[df['Combined'].str.contains('friend'), 'Communication and new friends'] = 1 
df.loc[df['Combined'].str.contains('Friend'), 'Communication and new friends'] = 1 
df.loc[df['Combined'].str.contains('express'), 'Communication and new friends'] = 1 
df.loc[df['Combined'].str.contains('Express'), 'Communication and new friends'] = 1 
df.loc[df['Combined'].str.contains('交流'), 'Communication and new friends'] = 1 
df.loc[df['Combined'].str.contains('溝通'), 'Communication and new friends'] = 1 
df.loc[df['Combined'].str.contains('朋友'), 'Communication and new friends'] = 1 
df.loc[df['Combined'].str.contains('待人'), 'Communication and new friends'] = 1 
df.loc[df['Combined'].str.contains('人際'), 'Communication and new friends'] = 1 
df.loc[df['Combined'].str.contains('交往'), 'Communication and new friends'] = 1 
df.loc[df['Combined'].str.contains('社交'), 'Communication and new friends'] = 1 
df.loc[df['Combined'].str.contains('相處'), 'Communication and new friends'] = 1 
df.loc[df['Combined'].str.contains('友'), 'Communication and new friends'] = 1 
df.loc[df['Combined'].str.contains('為人'), 'Communication and new friends'] = 1 
df.loc[df['Combined'].str.contains('表達'), 'Communication and new friends'] = 1 
df.loc[df['Combined'].str.contains('英文'), 'Communication and new friends'] = 1 
df.loc[df['Combined'].str.contains('英語'), 'Communication and new friends'] = 1 
df.loc[df['Combined'].str.contains('English'), 'Communication and new friends'] = 1 
df.loc[df['Combined'].str.contains('english'), 'Communication and new friends'] = 1 
df.loc[df['Combined'].str.contains('口語'), 'Communication and new friends'] = 1

# %%
df.loc[df['Combined'].str.contains('challeng'), 'Challenge'] = 1 
df.loc[df['Combined'].str.contains('Challeng'), 'Challenge'] = 1 
df.loc[df['Combined'].str.contains('挑戰'), 'Challenge'] = 1 
df.loc[df['Combined'].str.contains('鍛煉'), 'Challenge'] = 1 
df.loc[df['Combined'].str.contains('訓練'), 'Challenge'] = 1 
df.loc[df['Combined'].str.contains('歷練'), 'Challenge'] = 1 
df.loc[df['Combined'].str.contains('不足'), 'Challenge'] = 1

# %%
df.loc[df['Combined'].str.contains('經驗'), 'Creative and new experience'] = 1 
df.loc[df['Combined'].str.contains('經歷'), 'Creative and new experience'] = 1 
df.loc[df['Combined'].str.contains('體驗'), 'Creative and new experience'] = 1 
df.loc[df['Combined'].str.contains('課外'), 'Creative and new experience'] = 1 
df.loc[df['Combined'].str.contains('未知'), 'Creative and new experience'] = 1 
df.loc[df['Combined'].str.contains('眼界'), 'Creative and new experience'] = 1 
df.loc[df['Combined'].str.contains('眼見'), 'Creative and new experience'] = 1 
df.loc[df['Combined'].str.contains('experience'), 'Creative and new experience'] = 1 
df.loc[df['Combined'].str.contains('Experience'), 'Creative and new experience'] = 1 
df.loc[df['Combined'].str.contains('新'), 'Creative and new experience'] = 1 
df.loc[df['Combined'].str.contains('豐富'), 'Creative and new experience'] = 1 
df.loc[df['Combined'].str.contains('Fresh'), 'Creative and new experience'] = 1 
df.loc[df['Combined'].str.contains('fresh'), 'Creative and new experience'] = 1 
df.loc[df['Combined'].str.contains('curious'), 'Creative and new experience'] = 1 
df.loc[df['Combined'].str.contains('Curious'), 'Creative and new experience'] = 1 
df.loc[df['Combined'].str.contains('curiosity'), 'Creative and new experience'] = 1 
df.loc[df['Combined'].str.contains('Curiosity'), 'Creative and new experience'] = 1 
df.loc[df['Combined'].str.contains('explore'), 'Creative and new experience'] = 1 
df.loc[df['Combined'].str.contains('Explore'), 'Creative and new experience'] = 1 
df.loc[df['Combined'].str.contains('different'), 'Creative and new experience'] = 1 
df.loc[df['Combined'].str.contains('Different'), 'Creative and new experience'] = 1 

df.loc[df['Combined'].str.contains('creat'), 'Creative and new experience'] = 1 
df.loc[df['Combined'].str.contains('Creat'), 'Creative and new experience'] = 1 
df.loc[df['Combined'].str.contains('Innova'), 'Creative and new experience'] = 1 
df.loc[df['Combined'].str.contains('innova'), 'Creative and new experience'] = 1 
df.loc[df['Combined'].str.contains('imagi'), 'Creative and new experience'] = 1 
df.loc[df['Combined'].str.contains('Imagi'), 'Creative and new experience'] = 1 
df.loc[df['Combined'].str.contains('創造'), 'Creative and new experience'] = 1 
df.loc[df['Combined'].str.contains('創新'), 'Creative and new experience'] = 1 
df.loc[df['Combined'].str.contains('探索'), 'Creative and new experience'] = 1 
df.loc[df['Combined'].str.contains('好奇'), 'Creative and new experience'] = 1 
df.loc[df['Combined'].str.contains('未接觸'), 'Creative and new experience'] = 1 
df.loc[df['Combined'].str.contains('接觸不到'), 'Creative and new experience'] = 1 
df.loc[df['Combined'].str.contains('學不到'), 'Creative and new experience'] = 1 
df.loc[df['Combined'].str.contains('見識'), 'Creative and new experience'] = 1 
df.loc[df['Combined'].str.contains('見聞'), 'Creative and new experience'] = 1 
df.loc[df['Combined'].str.contains('廣闊'), 'Creative and new experience'] = 1 
df.loc[df['Combined'].str.contains('履歷'), 'Creative and new experience'] = 1 
df.loc[df['Combined'].str.contains('世面'), 'Creative and new experience'] = 1 
df.loc[df['Combined'].str.contains('horizon'), 'Creative and new experience'] = 1 
df.loc[df['Combined'].str.contains('Horizon'), 'Creative and new experience'] = 1 


df.loc[df['Combined'].str.contains('風俗'), 'Creative and new experience'] = 1 
df.loc[df['Combined'].str.contains('風土'), 'Creative and new experience'] = 1 
df.loc[df['Combined'].str.contains('美景'), 'Creative and new experience'] = 1 
df.loc[df['Combined'].str.contains('視野'), 'Creative and new experience'] = 1 
df.loc[df['Combined'].str.contains('括'), 'Creative and new experience'] = 1 
df.loc[df['Combined'].str.contains('不平凡'), 'Creative and new experience'] = 1 
df.loc[df['Combined'].str.contains('不一樣'), 'Creative and new experience'] = 1 
df.loc[df['Combined'].str.contains('尋找'), 'Creative and new experience'] = 1 
df.loc[df['Combined'].str.contains('音樂'), 'Creative and new experience'] = 1 
df.loc[df['Combined'].str.contains('fruitful'), 'Creative and new experience'] = 1 
df.loc[df['Combined'].str.contains('achieve'), 'Creative and new experience'] = 1 
df.loc[df['Combined'].str.contains('Achieve'), 'Creative and new experience'] = 1

# %%
df.loc[df['Combined'].str.contains('team'), 'Teamwork and leadership'] = 1 
df.loc[df['Combined'].str.contains('Team'), 'Teamwork and leadership'] = 1 
df.loc[df['Combined'].str.contains('lead'), 'Teamwork and leadership'] = 1 
df.loc[df['Combined'].str.contains('Lead'), 'Teamwork and leadership'] = 1 
df.loc[df['Combined'].str.contains('coopera'), 'Teamwork and leadership'] = 1 
df.loc[df['Combined'].str.contains('Coopera'), 'Teamwork and leadership'] = 1 
df.loc[df['Combined'].str.contains('合作'), 'Teamwork and leadership'] = 1 
df.loc[df['Combined'].str.contains('團隊'), 'Teamwork and leadership'] = 1 
df.loc[df['Combined'].str.contains('團結'), 'Teamwork and leadership'] = 1 
df.loc[df['Combined'].str.contains('團體'), 'Teamwork and leadership'] = 1 
df.loc[df['Combined'].str.contains('領'), 'Teamwork and leadership'] = 1 
df.loc[df['Combined'].str.contains('配合'), 'Teamwork and leadership'] = 1 
df.loc[df['Combined'].str.contains('組織'), 'Teamwork and leadership'] = 1 
df.loc[df['Combined'].str.contains('協'), 'Teamwork and leadership'] = 1

# %%
df.loc[df['Combined'].str.contains('stem'), 'STEM'] = 1 
df.loc[df['Combined'].str.contains('Stem'), 'STEM'] = 1 
df.loc[df['Combined'].str.contains('STEM'), 'STEM'] = 1 
df.loc[df['Combined'].str.contains('Science'), 'STEM'] = 1 
df.loc[df['Combined'].str.contains('science'), 'STEM'] = 1 
df.loc[df['Combined'].str.contains('Tech'), 'STEM'] = 1 
df.loc[df['Combined'].str.contains('tech'), 'STEM'] = 1 
df.loc[df['Combined'].str.contains('math'), 'STEM'] = 1 
df.loc[df['Combined'].str.contains('Math'), 'STEM'] = 1 
df.loc[df['Combined'].str.contains('engineer'), 'STEM'] = 1 
df.loc[df['Combined'].str.contains('Engineer'), 'STEM'] = 1 
df.loc[df['Combined'].str.contains('computer'), 'STEM'] = 1 
df.loc[df['Combined'].str.contains('Computer'), 'STEM'] = 1 
df.loc[df['Combined'].str.contains('bio'), 'STEM'] = 1 
df.loc[df['Combined'].str.contains('Bio'), 'STEM'] = 1 
df.loc[df['Combined'].str.contains('Chem'), 'STEM'] = 1 
df.loc[df['Combined'].str.contains('chem'), 'STEM'] = 1 
df.loc[df['Combined'].str.contains('Physi'), 'STEM'] = 1 
df.loc[df['Combined'].str.contains('physi'), 'STEM'] = 1 

df.loc[df['Combined'].str.contains('科學'), 'STEM'] = 1 
df.loc[df['Combined'].str.contains('電腦'), 'STEM'] = 1 
df.loc[df['Combined'].str.contains('數學'), 'STEM'] = 1 
df.loc[df['Combined'].str.contains('科技'), 'STEM'] = 1 
df.loc[df['Combined'].str.contains('工程'), 'STEM'] = 1 
df.loc[df['Combined'].str.contains('技術'), 'STEM'] = 1 
df.loc[df['Combined'].str.contains('理科'), 'STEM'] = 1 
df.loc[df['Combined'].str.contains('物理'), 'STEM'] = 1 
df.loc[df['Combined'].str.contains('化學'), 'STEM'] = 1 
df.loc[df['Combined'].str.contains('生物'), 'STEM'] = 1 
df.loc[df['Combined'].str.contains('技能'), 'STEM'] = 1 
df.loc[df['Combined'].str.contains('編程'), 'STEM'] = 1 
df.loc[df['Combined'].str.contains('計算機'), 'STEM'] = 1

# %%
df.loc[df['Combined'].str.contains('grow'), 'Personal growth'] = 1 
df.loc[df['Combined'].str.contains('Grow'), 'Personal growth'] = 1 
df.loc[df['Combined'].str.contains('improve'), 'Personal growth'] = 1 
df.loc[df['Combined'].str.contains('Improve'), 'Personal growth'] = 1 
df.loc[df['Combined'].str.contains('know'), 'Personal growth'] = 1 
df.loc[df['Combined'].str.contains('Know'), 'Personal growth'] = 1 
df.loc[df['Combined'].str.contains('learn'), 'Personal growth'] = 1 
df.loc[df['Combined'].str.contains('Learn'), 'Personal growth'] = 1 
df.loc[df['Combined'].str.contains('confident'), 'Personal growth'] = 1 
df.loc[df['Combined'].str.contains('Confident'), 'Personal growth'] = 1 
df.loc[df['Combined'].str.contains('confidence'), 'Personal growth'] = 1 
df.loc[df['Combined'].str.contains('Confidence'), 'Personal growth'] = 1 

df.loc[df['Combined'].str.contains('Better'), 'Personal growth'] = 1 
df.loc[df['Combined'].str.contains('better'), 'Personal growth'] = 1 
df.loc[df['Combined'].str.contains('mature'), 'Personal growth'] = 1 
df.loc[df['Combined'].str.contains('Mature'), 'Personal growth'] = 1 
df.loc[df['Combined'].str.contains('potential'), 'Personal growth'] = 1 
df.loc[df['Combined'].str.contains('Potential'), 'Personal growth'] = 1 
df.loc[df['Combined'].str.contains('Myself'), 'Personal growth'] = 1 
df.loc[df['Combined'].str.contains('myself'), 'Personal growth'] = 1 


df.loc[df['Combined'].str.contains('自我'), 'Personal growth'] = 1 
df.loc[df['Combined'].str.contains('能力'), 'Personal growth'] = 1 
df.loc[df['Combined'].str.contains('技巧'), 'Personal growth'] = 1 
df.loc[df['Combined'].str.contains('提升'), 'Personal growth'] = 1 
df.loc[df['Combined'].str.contains('改善'), 'Personal growth'] = 1 
df.loc[df['Combined'].str.contains('增長'), 'Personal growth'] = 1 
df.loc[df['Combined'].str.contains('改變'), 'Personal growth'] = 1 
df.loc[df['Combined'].str.contains('突破'), 'Personal growth'] = 1 
df.loc[df['Combined'].str.contains('提高'), 'Personal growth'] = 1 
df.loc[df['Combined'].str.contains('達成'), 'Personal growth'] = 1 

df.loc[df['Combined'].str.contains('自信'), 'Personal growth'] = 1 
df.loc[df['Combined'].str.contains('責任'), 'Personal growth'] = 1 
df.loc[df['Combined'].str.contains('負責'), 'Personal growth'] = 1 
df.loc[df['Combined'].str.contains('知識'), 'Personal growth'] = 1 
df.loc[df['Combined'].str.contains('了解'), 'Personal growth'] = 1 
df.loc[df['Combined'].str.contains('思考'), 'Personal growth'] = 1 
df.loc[df['Combined'].str.contains('變成'), 'Personal growth'] = 1 
df.loc[df['Combined'].str.contains('更好'), 'Personal growth'] = 1 
df.loc[df['Combined'].str.contains('充實'), 'Personal growth'] = 1 
df.loc[df['Combined'].str.contains('成長'), 'Personal growth'] = 1 


df.loc[df['Combined'].str.contains('承擔'), 'Personal growth'] = 1 
df.loc[df['Combined'].str.contains('成功'), 'Personal growth'] = 1 
df.loc[df['Combined'].str.contains('優秀'), 'Personal growth'] = 1 
df.loc[df['Combined'].str.contains('勇氣'), 'Personal growth'] = 1 
df.loc[df['Combined'].str.contains('膽'), 'Personal growth'] = 1 
df.loc[df['Combined'].str.contains('抗逆'), 'Personal growth'] = 1 
df.loc[df['Combined'].str.contains('處事'), 'Personal growth'] = 1 
df.loc[df['Combined'].str.contains('加強'), 'Personal growth'] = 1 
df.loc[df['Combined'].str.contains('益'), 'Personal growth'] = 1 
df.loc[df['Combined'].str.contains('價值'), 'Personal growth'] = 1 
df.loc[df['Combined'].str.contains('培養'), 'Personal growth'] = 1 
df.loc[df['Combined'].str.contains('外向'), 'Personal growth'] = 1 
df.loc[df['Combined'].str.contains('內向'), 'Personal growth'] = 1 
df.loc[df['Combined'].str.contains('認識'), 'Personal growth'] = 1 

df.loc[df['Combined'].str.contains('problem'), 'Personal growth'] = 1 
df.loc[df['Combined'].str.contains('Problem'), 'Personal growth'] = 1 
df.loc[df['Combined'].str.contains('問題'), 'Personal growth'] = 1 
df.loc[df['Combined'].str.contains('困難'), 'Personal growth'] = 1 
df.loc[df['Combined'].str.contains('本領'), 'Personal growth'] = 1 
df.loc[df['Combined'].str.contains('技巧'), 'Personal growth'] = 1 
df.loc[df['Combined'].str.contains('耐心'), 'Personal growth'] = 1

# %%
df.loc[df['Combined'].str.contains('趣'), 'Interest and fun'] = 1 

df.loc[df['Combined'].str.contains('玩'), 'Interest and fun'] = 1 
df.loc[df['Combined'].str.contains('喜歡'), 'Interest and fun'] = 1 
df.loc[df['Combined'].str.contains('熱愛'), 'Interest and fun'] = 1 
df.loc[df['Combined'].str.contains('開心'), 'Interest and fun'] = 1 
df.loc[df['Combined'].str.contains('interest'), 'Interest and fun'] = 1 
df.loc[df['Combined'].str.contains('Interest'), 'Interest and fun'] = 1 
df.loc[df['Combined'].str.contains('fun'), 'Interest and fun'] = 1 
df.loc[df['Combined'].str.contains('Fun'), 'Interest and fun'] = 1 
df.loc[df['Combined'].str.contains('excit'), 'Interest and fun'] = 1 
df.loc[df['Combined'].str.contains('Excit'), 'Interest and fun'] = 1 

df.loc[df['Combined'].str.contains('高興'), 'Interest and fun'] = 1 
df.loc[df['Combined'].str.contains('吸引'), 'Interest and fun'] = 1 

df.loc[df['Combined'].str.contains('attract'), 'Interest and fun'] = 1 
df.loc[df['Combined'].str.contains('Attract'), 'Interest and fun'] = 1 
df
# Out:
#                                               Combined  School  \
# 0                                 我想看到自己能力的不足學到如何成為領導者       0
# 1                             認識更多朋友，提升自己能力英文提升，動手能力提升       0
# 2                                   因為我覺得他可以提升自己的英語的能力       0
# 3                                       增加自己的履歷堅強不放棄團結       0
# 4                                            見見世面英語，成長       0
# 5                                             想要鍛煉自己團結       0
# 6                                          為了鍛煉領導力更多知識       0
# 7                                             學習領導力，團結       0
# 8                                               學習體驗知識       0
# 9      機會難得 可以接觸國際上的朋友 和他們一起交流的學習可以學到一些在學校學不到的東西 提高自信心       1
# 10                                            體驗學習知識智慧       0
# 11                           想學到不一樣的知識提高自己的積極性  主動動手能力       0
# 12                                         我喜歡挑戰創造力和知識       0
# 13                                            暑假提升自己創新       0
# ...

# %%
School=sum(df['School'])
Communication_and_new_friends=sum(df['Communication and new friends'])
Challenge=sum(df['Challenge'])
Creative_and_new_experience=sum(df['Creative and new experience'])
Teamwork_and_Leadership=sum(df['Teamwork and leadership'])
STEM=sum(df['STEM'])
Personal_Growth=sum(df['Personal growth'])
Interest_and_fun=sum(df['Interest and fun'])

# %%
data = {'Category': ['School', 'Communication_and_new_friends', 'Challenge', 'Creative_and_new_experience','Teamwork_and_Leadership','STEM','Personal_Growth','Interest_and_fun'], 'Count': [School, Communication_and_new_friends, Challenge, Creative_and_new_experience,Teamwork_and_Leadership,STEM,Personal_Growth,Interest_and_fun]}  
data=pd.DataFrame(data)
data=data.sort_values(by='Count',ascending=False)
data.set_index('Category',inplace=True)
print(data)
# Out:
#                                Count
# Category
# Personal_Growth                  378
# Communication_and_new_friends    242
# Teamwork_and_Leadership          240
# Creative_and_new_experience      183
# Challenge                        109
# Interest_and_fun                  97
# STEM                              60
# School                            18

# %%
import matplotlib.pyplot as plt

data = data
fig, ax = plt.subplots()
data.plot(ax=ax, kind='barh')
plt.gca().invert_yaxis()

# %%
# create excel writer object
writer = pd.ExcelWriter('output.xlsx')
# write dataframe to excel
df.to_excel(writer)
# save the excel
writer.save()
