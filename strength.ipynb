# %%
import pandas as pd
import numpy as np
pd.set_option("display.max_rows", None, "display.max_columns", None)

# %%
df=pd.read_excel('2018_strength.xlsx')
df
# Out:
#     Name one of your strengths and how you may use it to add values to the others. 說出你的一個強項，以及你會如何運用這個強項為別人增值。  \
# 0    Responsible\nI do everything hard, even if i c...
# 1                                                附出為大家
# 2                                      計算，與別人分享自己的計算方法
# 3                                          創意力，為團隊設計海報
# 4                                           intergrity
# 5    I will teach others to face challenge with a p...
# 6              Lot of ideas ，I can tell  my teammates
# 7                      I think I can teach them music.
# 8    I am a person who have many ideas ,I will use ...
# 9                                領導能力好但不高，帶領別人了解更多新的事物
# 10   My English is better so I will try to learn mo...
# 11   My strengths is studying English. I am good at...
# 12                                      Be responsible
# 13                  I am good at using the electronic
# 14                                   勇敢，當別人害怕在某件事我可以幫忙
# ...

# %%
df_allo=df.iloc[:,1]
df_allo
# Out:
# 0             Teamwork and Leadership
# 1             Teamwork and Leadership
# 2                                STEM
# 3                          Creativity
# 4                                 NaN
# 5             Teamwork and Leadership
# 6                          Creativity
# 7                    Music and Dacing
# 8                          Creativity
# 9             Teamwork and Leadership
# 10                                NaN
# 11                            Writing
# 12            Teamwork and Leadership
# 13                               STEM
# 14            Teamwork and Leadership
# 15     Communication and Presentation
# 16            Teamwork and Leadership
# 17     Communication and Presentation
# 18                         Creativity
# 19                         Creativity
# 20            Teamwork and Leadership
# 21                                NaN
# 22            Teamwork and Leadership
# 23                         Confidence
# 24                       Art & Design
# ...

# %%
df_allo[(df_allo=='Music and Dacing')] = 'Music and Dancing'

# %%
import matplotlib.pyplot as plt

data_allo = df_allo
fig, ax = plt.subplots()
data_allo.value_counts().plot(ax=ax, kind='barh')
plt.gca().invert_yaxis()

# %%
df[df['Allocation']=='Teamwork and Leadership']
# Out:
#     Name one of your strengths and how you may use it to add values to the others. 說出你的一個強項，以及你會如何運用這個強項為別人增值。  \
# 0    Responsible\nI do everything hard, even if i c...
# 1                                                附出為大家
# 5    I will teach others to face challenge with a p...
# 9                                領導能力好但不高，帶領別人了解更多新的事物
# 12                                      Be responsible
# 14                                   勇敢，當別人害怕在某件事我可以幫忙
# 16                 我可以迅速融入不同崗位，頂替每一個漏掉的地方，為大家填補漏洞，邁向巔峰
# 20                                處理問題的能力，協助他人和教導如何解決。
# 22                                       組織力，組織和合作進行任務
# 30                                    work with others
# 31                                       helping othrs
# 32   Strong in organising team members, this makes ...
# 35                                  I can help others
# 36                        Lead the group on discussing
# 38                                 Good at cooperation
# ...

# %%
df = df.iloc[:,0]

# %%
df[df.str.contains('Respon', na=False)]='Teamwork & Leadership'
df[df.str.contains('respon', na=False)]='Teamwork & Leadership'

df[df.str.contains('Writ', na=False)]='Writing'
df[df.str.contains('writ', na=False)]='Writing'
df[df.str.contains('寫', na=False)]='Writing'
df[df.str.contains('文', na=False)]='Writing'
df[df.str.contains('書面', na=False)]='Writing'
df[df.str.contains('Script', na=False)]='Writing'
df[df.str.contains('script', na=False)]='Writing'
df[df.str.contains('稿', na=False)]='Writing'

# %%
df[df.str.contains('Music', na=False)]='Music and Dancing'
df[df.str.contains('music', na=False)]='Music and Dancing'
df[df.str.contains('歌', na=False)]='Music and Dancing'
df[df.str.contains('音樂', na=False)]='Music and Dancing'
df[df.str.contains('節奏', na=False)]='Music and Dancing'
df[df.str.contains('Danc', na=False)]='Music and Dancing'
df[df.str.contains('danc', na=False)]='Music and Dancing'

# %%
df[df.str.contains('Draw', na=False)]='Art & Design'
df[df.str.contains('draw', na=False)]='Art & Design'
df[df.str.contains('Design', na=False)]='Art & Design'
df[df.str.contains('design', na=False)]='Art & Design'
df[df.str.contains('繪', na=False)]='Art & Design'
df[df.str.contains('畫', na=False)]='Art & Design'
df[df.str.contains('設計', na=False)]='Art & Design'
df[df.str.contains('海報', na=False)]='Art & Design'
df[df.str.contains('poster', na=False)]='Art & Design'
df[df.str.contains('Poster', na=False)]='Art & Design'
df[df.str.contains('Art', na=False)]='Art & Design'
df[df.str.contains('art', na=False)]='Art & Design'
df[df.str.contains('藝術', na=False)]='Art & Design'

# %%
df[df.str.contains('聽', na=False)]='Communication and Presentation'
df[df.str.contains('溝', na=False)]='Communication and Presentation'
df[df.str.contains('Communi', na=False)]='Communication and Presentation'
df[df.str.contains('communi', na=False)]='Communication and Presentation'
df[df.str.contains('Talk', na=False)]='Communication and Presentation'
df[df.str.contains('talk', na=False)]='Communication and Presentation'
df[df.str.contains('Listen', na=False)]='Communication and Presentation'
df[df.str.contains('listen', na=False)]='Communication and Presentation'
df[df.str.contains('交流', na=False)]='Communication and Presentation'
df[df.str.contains('Listen', na=False)]='Communication and Presentation'
df[df.str.contains('表達', na=False)]='Communication and Presentation'
df[df.str.contains('Listen', na=False)]='Communication and Presentation'
df[df.str.contains('演講', na=False)]='Communication and Presentation'
df[df.str.contains('present', na=False)]='Communication and Presentation'
df[df.str.contains('Present', na=False)]='Communication and Presentation'
df[df.str.contains('讀', na=False)]='Communication and Presentation'
df[df.str.contains('話', na=False)]='Communication and Presentation'
df[df.str.contains('開心', na=False)]='Communication and Presentation'
df[df.str.contains('快樂', na=False)]='Communication and Presentation'
df[df.str.contains('口', na=False)]='Communication and Presentation'
df[df.str.contains('語言', na=False)]='Communication and Presentation'
df[df.str.contains('翻譯', na=False)]='Communication and Presentation'
df[df.str.contains('說', na=False)]='Communication and Presentation'

# %%
df[df.str.contains('創', na=False)]='Creativity'
df[df.str.contains('idea', na=False)]='Creativity'
df[df.str.contains('Idea', na=False)]='Creativity'
df[df.str.contains('Creat', na=False)]='Creativity'
df[df.str.contains('CREAT', na=False)]='Creativity'
df[df.str.contains('creat', na=False)]='Creativity'
df[df.str.contains('想法', na=False)]='Creativity'
df[df.str.contains('new', na=False)]='Creativity'
df[df.str.contains('New', na=False)]='Creativity'
df[df.str.contains('新', na=False)]='Creativity'
df[df.str.contains('想像', na=False)]='Creativity'
df[df.str.contains('幻想', na=False)]='Creativity'
df[df.str.contains('諗頭', na=False)]='Creativity'
df[df.str.contains('點子', na=False)]='Creativity'
df[df.str.contains('Creat', na=False)]='Creativity'
df[df.str.contains('思路', na=False)]='Creativity'
df[df.str.contains('思維', na=False)]='Creativity'
df[df.str.contains('腦洞', na=False)]='Creativity'
df[df.str.contains('idea', na=False)]='Creativity'
df[df.str.contains('妙想', na=False)]='Creativity'
df[df.str.contains('idea', na=False)]='Creativity'
df[df.str.contains('出謀', na=False)]='Creativity'
df[df.str.contains('不同於', na=False)]='Creativity'
df[df.str.contains('意見', na=False)]='Creativity'

# %%
df[df.str.contains('Math', na=False)]='STEM'
df[df.str.contains('math', na=False)]='STEM'
df[df.str.contains('數', na=False)]='STEM'
df[df.str.contains('算', na=False)]='STEM'
df[df.str.contains('Science', na=False)]='STEM'
df[df.str.contains('science', na=False)]='STEM'
df[df.str.contains('Comput', na=False)]='STEM'
df[df.str.contains('comput', na=False)]='STEM'
df[df.str.contains('電腦', na=False)]='STEM'
df[df.str.contains('生物', na=False)]='STEM'
df[df.str.contains('bio', na=False)]='STEM'
df[df.str.contains('Bio', na=False)]='STEM'
df[df.str.contains('app', na=False)]='STEM'
df[df.str.contains('App', na=False)]='STEM'
df[df.str.contains('APP', na=False)]='STEM'
df[df.str.contains('Physi', na=False)]='STEM'
df[df.str.contains('physi', na=False)]='STEM'
df[df.str.contains('物理', na=False)]='STEM'
df[df.str.contains('科學', na=False)]='STEM'
df[df.str.contains('electro', na=False)]='STEM'
df[df.str.contains('Electro', na=False)]='STEM'
df[df.str.contains('Calcu', na=False)]='STEM'
df[df.str.contains('昆蟲', na=False)]='STEM'

# %%
df[df.str.contains('Confi', na=False)]='Confidence'
df[df.str.contains('confi', na=False)]='Confidence'
df[df.str.contains('自信', na=False)]='Confidence'
df[df.str.contains('信心', na=False)]='Confidence'

# %%
df[df.str.contains('體諒', na=False)]='Empathy'
df[df.str.contains('feel', na=False)]='Empathy'
df[df.str.contains('care', na=False)]='Empathy'
df[df.str.contains('Care', na=False)]='Empathy'
df[df.str.contains('caring', na=False)]='Empathy'
df[df.str.contains('Caring', na=False)]='Empathy'

# %%
df[df.str.contains('team', na=False)]='Teamwork & Leadership'
df[df.str.contains('Team', na=False)]='Teamwork & Leadership'
df[df.str.contains('Coopera', na=False)]='Teamwork & Leadership'
df[df.str.contains('coopera', na=False)]='Teamwork & Leadership'
df[df.str.contains('合作', na=False)]='Teamwork & Leadership'
df[df.str.contains('work', na=False)]='Teamwork & Leadership'
df[df.str.contains('Work', na=False)]='Teamwork & Leadership'
df[df.str.contains('Group', na=False)]='Teamwork & Leadership'
df[df.str.contains('group', na=False)]='Teamwork & Leadership'
df[df.str.contains('團隊', na=False)]='Teamwork & Leadership'
df[df.str.contains('組織', na=False)]='Teamwork & Leadership'
df[df.str.contains('分工', na=False)]='Teamwork & Leadership'
df[df.str.contains('氣氛', na=False)]='Teamwork & Leadership'
df[df.str.contains('和諧', na=False)]='Teamwork & Leadership'
df[df.str.contains('配合', na=False)]='Teamwork & Leadership'
df[df.str.contains('Patience', na=False)]='Teamwork & Leadership'
df[df.str.contains('patience', na=False)]='Teamwork & Leadership'
df[df.str.contains('耐', na=False)]='Teamwork & Leadership'
df[df.str.contains('support', na=False)]='Teamwork & Leadership'
df[df.str.contains('Support', na=False)]='Teamwork & Leadership'
df[df.str.contains('後勤', na=False)]='Teamwork & Leadership'
df[df.str.contains('幫助', na=False)]='Teamwork & Leadership'
df[df.str.contains('崗位', na=False)]='Teamwork & Leadership'
df[df.str.contains('冷靜', na=False)]='Teamwork & Leadership'
df[df.str.contains('Calm', na=False)]='Teamwork & Leadership'
df[df.str.contains('calm', na=False)]='Teamwork & Leadership'
df[df.str.contains('他人', na=False)]='Teamwork & Leadership'
df[df.str.contains('共同', na=False)]='Teamwork & Leadership'
df[df.str.contains('增值', na=False)]='Teamwork & Leadership'

df[df.str.contains('help', na=False)]='Teamwork & Leadership'
df[df.str.contains('Help', na=False)]='Teamwork & Leadership'
df[df.str.contains('助', na=False)]='Teamwork & Leadership'
df[df.str.contains('鼓勵', na=False)]='Teamwork & Leadership'
df[df.str.contains('熱心', na=False)]='Teamwork & Leadership'

df[df.str.contains('認真', na=False)]='Teamwork & Leadership'
df[df.str.contains('負責', na=False)]='Teamwork & Leadership'
df[df.str.contains('責任', na=False)]='Teamwork & Leadership'
df[df.str.contains('開朗', na=False)]='Teamwork & Leadership'
df[df.str.contains('樂觀', na=False)]='Teamwork & Leadership'
df[df.str.contains('Positi', na=False)]='Teamwork & Leadership'
df[df.str.contains('positi', na=False)]='Teamwork & Leadership'
df[df.str.contains('hardwork', na=False)]='Teamwork & Leadership'
df[df.str.contains('Hardwork', na=False)]='Teamwork & Leadership'
df[df.str.contains('best', na=False)]='Teamwork & Leadership'
df[df.str.contains('Best', na=False)]='Teamwork & Leadership'
df[df.str.contains('守時', na=False)]='Teamwork & Leadership'
df[df.str.contains('全心', na=False)]='Teamwork & Leadership'
df[df.str.contains('optimis', na=False)]='Teamwork & Leadership'
df[df.str.contains('Optimis', na=False)]='Teamwork & Leadership'
df[df.str.contains('Lead', na=False)]='Teamwork & Leadership'
df[df.str.contains('lead', na=False)]= 'Teamwork & Leadership'
df[df.str.contains('領', na=False)]='Teamwork & Leadership'
df[df.str.contains('指揮', na=False)]='Teamwork & Leadership'
df[df.str.contains('lead', na=False)]='Teamwork & Leadership'
df[df.str.contains('為大家', na=False)]='Teamwork & Leadership'
df[df.str.contains('協', na=False)]='Teamwork & Leadership'
df[df.str.contains('教導', na=False)]='Teamwork & Leadership'
df[df.str.contains('幫忙', na=False)]='Teamwork & Leadership'
df[df.str.contains('Organi', na=False)]='Teamwork & Leadership'
df[df.str.contains('organi', na=False)]='Teamwork & Leadership'
df[df.str.contains('補充', na=False)]='Teamwork & Leadership'



df[df.str.contains('Thoughtful', na=False)]='Empathy'
df[df.str.contains('thoughtful', na=False)]='Empathy'
df[df.str.contains('needs', na=False)]='Empathy'
df[df.str.contains('Needs', na=False)]='Empathy'
df[df.str.contains('同理', na=False)]='Empathy'
df[df.str.contains('others', na=False)]='Empathy'
df[df.str.contains('Others', na=False)]='Empathy'

# %%
df[(df!= 'Creativity') & (df!= 'Art & Design') & (df!= 'Communication and Presentation') & (df!='Teamwork & Leadership') & (df!='STEM') & (df!='Writing') & (df!='Confidence') & (df!='Music and Dancing') & (df!='Empathy') ]='Others'
df
# Out:
# 0               Teamwork & Leadership
# 1               Teamwork & Leadership
# 2                                STEM
# 3                        Art & Design
# 4                              Others
# 5               Teamwork & Leadership
# 6                          Creativity
# 7                   Music and Dancing
# 8                          Creativity
# 9                          Creativity
# 10              Teamwork & Leadership
# 11                            Writing
# 12              Teamwork & Leadership
# 13                               STEM
# 14              Teamwork & Leadership
# 15     Communication and Presentation
# 16              Teamwork & Leadership
# 17     Communication and Presentation
# 18                         Creativity
# 19                         Creativity
# 20              Teamwork & Leadership
# 21                             Others
# 22              Teamwork & Leadership
# 23                         Confidence
# 24                       Art & Design
# ...

# %%
# create excel writer object
writer = pd.ExcelWriter('output.xlsx')
# write dataframe to excel
df.to_excel(writer)
# save the excel
writer.save()

# %%
df.replace('Others', np.nan, inplace=True)

# %%
import matplotlib.pyplot as plt

data = df
fig, ax = plt.subplots()
data.value_counts().plot(ax=ax, kind='barh')
plt.gca().invert_yaxis()
